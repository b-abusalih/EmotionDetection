# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("dataset_original.csv")

# %%
df
# Out:
#           ID                                               text  emotion  flag
# 0          1                            i didnt feel humiliated  sadness     1
# 1          2  i can go from feeling so hopeless to so damned...  sadness     1
# 2          3   im grabbing a minute to post i feel greedy wrong    anger     1
# 3          4  i am ever feeling nostalgic about the fireplac...     love     1
# 4          5                               i am feeling grouchy    anger     1
# ...      ...                                                ...      ...   ...
# 19995  20043  i just keep feeling like someone is being unki...    anger     1
# 19996  20044  im feeling a little cranky negative after this...    anger     1
# 19997  20045  i feel that i am useful to my people and that ...      joy     1
# 19998  20046  im feeling more comfortable with derby i feel ...      joy     1
# 19999  20047  i feel all weird when i have to meet w people ...     fear     1
#
# ...

# %%
plt.figure(figsize=(8,5),dpi=1200)

ax = sns.countplot(x="emotion", palette = "Set3", data=df)
plt.show()

# %%
df = pd.read_csv("textprobe.csv")
fig= sns.displot(data=df,palette="Set2")
fig.set_axis_labels( 'textprobe','Count')
sns.move_legend(fig, "lower center",
    bbox_to_anchor=(.5, 0.95), ncol=4, title=None, frameon=False,)
fig.savefig('textprobe.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("textprobe.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'textprobe','Count')
fig.savefig('textprobe.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("crystalfeel.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'crystalfeel','Count')
fig.savefig('crystalfeel.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("nlpcloud.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'nlpcloud','Count')
fig.savefig('nlpcloud.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("paralleldots_emotions.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'paralleldots_emotions','Count')
fig.savefig('paralleldots_emotions.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("senpy.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'senpy','Count')
fig.savefig('senpy.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("symanto_ekman.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'symanto_ekman','Count')
fig.savefig('symanto_ekman.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("text2emotions.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'text2emotions','Count')
fig.savefig('text2emotions.jpg', format='jpeg', dpi=600)

# %%
df = pd.read_csv("ibm_nlu.csv")
fig= sns.displot(data=df,palette="Set2",legend=False)
fig.set_axis_labels( 'ibm_nlu','Count')
fig.savefig('ibm_nlu.jpg', format='jpeg', dpi=600)
